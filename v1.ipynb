# %%
import numpy as np
import matplotlib as mpl
import seaborn as sb
import pandas as pd

# %%
raw_data = pd.read_csv("wetterdaten_CSV.csv")

raw_data.head()
# Out:
#         Datum   Zeit  Aussentemp  Luftfeuchte  Luftdruck  Regenmenge  Wind  \
# 0  01.01.2015  00:00         0.8           95       1029         0.0   0.0
# 1  01.01.2015  00:03         0.8           95       1029         0.0   0.0
# 2  01.01.2015  00:06         0.8           95       1029         0.0   0.0
# 3  01.01.2015  00:09         0.8           95       1029         0.0   0.0
# 4  01.01.2015  00:12         0.8           95       1029         0.0   0.0
#
#    Richtung  Helligkeit      DatumUndZeit
# 0       320           0  01.01.2015 00:00
# 1       320           0  01.01.2015 00:03
# 2       320           0  01.01.2015 00:06
# 3       320           0  01.01.2015 00:09
# 4       320           0  01.01.2015 00:12
